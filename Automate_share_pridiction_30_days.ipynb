# %%
## Switch to GPU mode for faster Computation (Runtime> Change runtime> GPU)

# %%
# %pip install pystan==2.18.0.0
# %pip install fbprophet
# %pip install pandas
# %pip install plotly.express
# %pip install plotly.io

# %%
# %pip install fbprophet
# Out:
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting Cython>=0.22
#   Using cached Cython-0.29.33-py2.py3-none-any.whl (987 kB)
# Collecting cmdstanpy==0.9.5
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14
#   Using cached pystan-3.6.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\anant\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fbprophet) (1.24.1)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\anant\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fbprophet) (1.5.3)
# Collecting matplotlib>=2.0.0
#   Using cached matplotlib-3.6.3-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting LunarCalendar>=0.0.9
#   Using cached LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Using cached convertdate-2.4.0-py3-none-any.whl (47 kB)
# Collecting holidays>=0.10.2
#   Using cached holidays-0.18-py3-none-any.whl (195 kB)
# Collecting setuptools-git>=1.2
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\anant\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fbprophet) (2.8.2)
# Collecting tqdm>=4.36.1
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Collecting pymeeus<=1,>=0.3.13
#   Using cached PyMeeus-0.5.12.tar.gz (5.8 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting korean-lunar-calendar
#   Using cached korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting hijri-converter
#   Using cached hijri_converter-2.2.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: pytz in c:\users\anant\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from LunarCalendar>=0.0.9->fbprophet) (2022.7.1)
# Collecting ephem>=3.7.5.3
#   Using cached ephem-4.1.4-cp310-cp310-win_amd64.whl (1.4 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp310-cp310-win_amd64.whl (162 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-cp310-cp310-win_amd64.whl (2.5 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\anant\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=2.0.0->fbprophet) (23.0)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting pystan>=2.14
#   Using cached pystan-3.5.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.4.0-py3-none-any.whl (13 kB)
# Collecting clikit<0.7,>=0.6
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Collecting pystan>=2.14
#   Using cached pystan-3.3.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.2.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.1.1-py3-none-any.whl (13 kB)
#   Using cached pystan-3.1.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.0.2-py3-none-any.whl (13 kB)
#   Using cached pystan-3.0.1-py3-none-any.whl (12 kB)
#   Using cached pystan-3.0.0-py3-none-any.whl (12 kB)
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\anant\AppData\Local\Temp\pip-install-7r_ulw4k\pystan_51d313aa4b1d48d695b2b523ae02fca0\setup.py", line 122, in <module>
#           from Cython.Build.Inline import _get_build_extension
#       ModuleNotFoundError: No module named 'Cython'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import plotly.express as px
from fbprophet import Prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import plotly.express as px
# ----> 3 from fbprophet import Prophet
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
import plotly.io as pio
pio.renderers.default='colab'

# %%
df=pd.read_csv("exide.csv")

# %%
df

# %%
df.info()

# %%
df.describe()

# %%
px.area(df, x="Date", y="Close ")

# %%
px.line(df, x="Date", y="Close")

# %%
px.area(df, x="Date", y="Volume")

# %%
px.box(df, y="Close")

# %%
px.bar(df, x="Date", y="Volume")

# %%
df

# %%
columns=['Date',"Close Price"]
ndf=pd.DataFrame(df, columns=columns)

# %%
ndf

# %%
pdf = ndf.rename(columns = {'Date':'ds', 'Close Price':'y'})

# %%
pdf

# %%
m=Prophet()

# %%
m.fit(pdf)

# %%
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)

# %%
forecast

# %%
px.line(forecast, x='ds', y='yhat')

# %%
figure = m.plot(forecast, xlabel='ds',ylabel='y')

# %%
figure2 = m.plot_components(forecast)

# %%
from google.colab import files
forecast.to_csv('forecast.csv')
files.download('forecast.csv')
